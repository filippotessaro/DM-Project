# %% [markdown]
# # **Sintetic Dataset Generator**
# ### **Input Data**
# #### Fill the *association_rules* array like in this example
# It is a tuple representing:
# - The 1<sup>st</sup> element is the **left** part of the Association Rule
# - The 2<sup>nd</sup> element is the **right** part of the Association Rule
# - The 3<sup>rd</sup> element is the **confidence** of the Association Rule (it is used for defining how likely is the generation of a similar basket)
# - The 4<sup>th</sup> element is the **interest** of the Association Rule (currently it is not used)
#
# #### Basket *Dataset size*
# In the other cell you can define the number of basket to generate

# %%
association_rules = []
association_rules.append((['yogurt'], ['whole milk'], 0.40160349854227406, 0.2621159019582968))
association_rules.append((['butter'], ['whole milk'], 0.4972477064220184, 0.44183900369733353))
association_rules.append((['chicken'], ['whole milk'], 0.4099526066350711, 0.3670489872776087))
association_rules.append((['sugar'], ['whole milk'], 0.4444444444444444, 0.41058921874293974))
association_rules.append((['process chees'], ['whole milk'], 0.4233128834355828, 0.40674110629040183))
association_rules.append((['root veget'], ['whole milk'], 0.44869402985074625, 0.33970663660145795))
association_rules.append((['whippedsour cream'], ['whole milk'], 0.44964539007092197, 0.37796991223440307))
association_rules.append((['domest egg'], ['whole milk'], 0.47275641025641024, 0.4093159873202573))
association_rules.append((['hard chees'], ['whole milk'], 0.4107883817427386, 0.3862865517305385))
association_rules.append((['ham'], ['whole milk'], 0.44140625, 0.41537940982106547))
association_rules.append((['frozen veget'], ['whole milk'], 0.4249471458773784, 0.3768584919530189))
association_rules.append((['soft chees'], ['whole milk'], 0.44047619047619047, 0.42339607660876466))
association_rules.append((['margarin'], ['whole milk'], 0.4131944444444444, 0.35463405404184173))
association_rules.append((['semifinish bread'], ['whole milk'], 0.40229885057471265, 0.3846087326405931))
association_rules.append((['tropic fruit'], ['whole milk'], 0.40310077519379844, 0.29818007572246863))
association_rules.append((['cream chees'], ['whole milk'], 0.4153846153846154, 0.37573435104951985))
association_rules.append((['pot plant'], ['whole milk'], 0.4, 0.38271655144367633))
association_rules.append((['white bread'], ['whole milk'], 0.4057971014492754, 0.3637068208474047))
association_rules.append((['flour'], ['whole milk'], 0.4853801169590643, 0.4679950010582916))
association_rules.append((['curd'], ['whole milk'], 0.4904580152671756, 0.43718432677591895))
association_rules.append((['beef'], ['whole milk'], 0.4050387596899225, 0.3525784099542576))
association_rules.append((['butter milk'], ['whole milk'], 0.41454545454545455, 0.38658693482198975))
association_rules.append((['deterg'], ['whole milk'], 0.4656084656084656, 0.44639333750761157))
association_rules.append((['hamburg meat'], ['whole milk'], 0.4434250764525994, 0.41017985481778846))
association_rules.append((['bake powder'], ['whole milk'], 0.5229885057471264, 0.5052983878130068))
association_rules.append((['oil'], ['whole milk'], 0.40217391304347827, 0.37411372597556447))
association_rules.append((['herb'], ['whole milk'], 0.475, 0.4587332248881659))
association_rules.append((['slice chees'], ['whole milk'], 0.43983402489626555, 0.4153321948840655))
association_rules.append((['pasta'], ['whole milk'], 0.40540540540540543, 0.3903586384269589))
association_rules.append((['cake bar'], ['whole milk'], 0.4230769230769231, 0.40986016829855787))
association_rules.append((['mustard'], ['whole milk'], 0.4322033898305085, 0.42020664318553086))
association_rules.append((['chicken'], ['veget'], 0.41706161137440756, 0.37415799201694516))
association_rules.append((['root veget'], ['veget'], 0.43470149253731344, 0.3257140992880251))
association_rules.append((['herb'], ['root veget'], 0.43125, 0.41498322488816597))
association_rules.append((['whippedsour cream'], ['veget'], 0.40283687943262414, 0.33116140159610524))
association_rules.append((['onion'], ['veget'], 0.45901639344262296, 0.42800785338568925))
association_rules.append((['soft chees'], ['veget'], 0.4166666666666667, 0.3995865527992409))
association_rules.append((['hamburg meat'], ['veget'], 0.41590214067278286, 0.38265691903797194))
association_rules.append((['grape'], ['veget'], 0.40454545454545454, 0.3821786387666827))
association_rules.append((['bake powder'], ['veget'], 0.41379310344827586, 0.3961029855141563))
association_rules.append((['herb'], ['veget'], 0.475, 0.4587332248881659))
association_rules.append((['coffe', 'yogurt'], ['whole milk'], 0.5208333333333334, 0.5110732682662329))
association_rules.append((['veget', 'coffe'], ['whole milk'], 0.4772727272727273, 0.46385263780546415))
association_rules.append((['yogurt', 'citru fruit'], ['whole milk'], 0.47417840375586856, 0.45252325938823945))
association_rules.append((['yogurt', 'tropic fruit'], ['whole milk'], 0.5173611111111112, 0.48808091590980984))
association_rules.append((['yogurt', 'bottl water'], ['whole milk'], 0.42035398230088494, 0.3973771624554193))
association_rules.append((['pip fruit', 'yogurt'], ['whole milk'], 0.5310734463276836, 0.5130783263602171))
association_rules.append((['pip fruit', 'yogurt'], ['veget'], 0.4519774011299435, 0.43398228116247706))
association_rules.append((['butter', 'yogurt'], ['whole milk'], 0.6388888888888888, 0.6242487912882382))
association_rules.append((['rollsbun', 'yogurt'], ['whole milk'], 0.4526627218934911, 0.4182991594697416))
association_rules.append((['newspap', 'yogurt'], ['whole milk'], 0.4304635761589404, 0.41511180714714696))
association_rules.append((['fruitveget juic', 'yogurt'], ['whole milk'], 0.5054347826086957, 0.4867279912300865))
association_rules.append((['fruitveget juic', 'yogurt'], ['veget'], 0.44021739130434784, 0.42151059992573864))
association_rules.append((['pastri', 'yogurt'], ['whole milk'], 0.5172413793103449, 0.4995512613762253))
association_rules.append((['root veget', 'yogurt'], ['whole milk'], 0.562992125984252, 0.5371686204942153))
association_rules.append((['brown bread', 'yogurt'], ['whole milk'], 0.48951048951048953, 0.4749720592542878))
association_rules.append((['napkin', 'yogurt'], ['whole milk'], 0.49586776859504134, 0.4835660199167168))
association_rules.append((['whippedsour cream', 'yogurt'], ['whole milk'], 0.5245098039215687, 0.5037696656539802))
association_rules.append((['whippedsour cream', 'tropic fruit'], ['yogurt'], 0.4485294117647059, 0.43470265291964694))
association_rules.append((['whippedsour cream', 'yogurt'], ['veget'], 0.49019607843137253, 0.46945594016378406))
association_rules.append((['domest egg', 'yogurt'], ['whole milk'], 0.5390070921985816, 0.5246719966312777))
association_rules.append((['domest egg', 'yogurt'], ['veget'], 0.40425531914893614, 0.38992022358163236))
association_rules.append((['frozen veget', 'yogurt'], ['whole milk'], 0.4918032786885246, 0.4793998626657511))
association_rules.append((['margarin', 'yogurt'], ['whole milk'], 0.4928571428571429, 0.47862371463428804))
association_rules.append((['margarin', 'yogurt'], ['veget'], 0.4, 0.3857665717771452))
association_rules.append((['cream chees', 'whole milk'], ['yogurt'], 0.4012345679012346, 0.3847644581005026))
association_rules.append((['cream chees', 'yogurt'], ['whole milk'], 0.5327868852459017, 0.5203834692231282))
association_rules.append((['veget', 'yogurt'], ['whole milk'], 0.5128805620608899, 0.46946860598118273))
association_rules.append((['butter', 'yogurt'], ['veget'], 0.4375, 0.42285990239934934))
association_rules.append((['root veget', 'yogurt'], ['veget'], 0.5, 0.4741764945099634))
association_rules.append((['frozen veget', 'yogurt'], ['veget'], 0.4262295081967213, 0.4138260921739478))
association_rules.append((['yogurt', 'tropic fruit'], ['veget'], 0.4201388888888889, 0.3908586936875876))
association_rules.append((['cream chees', 'yogurt'], ['veget'], 0.4262295081967213, 0.4138260921739478))
association_rules.append((['beef', 'yogurt'], ['veget'], 0.4434782608695652, 0.43178651625793446))
association_rules.append((['bottl beer', 'yogurt'], ['whole milk'], 0.5604395604395604, 0.5511878320947048))
association_rules.append((['curd', 'yogurt'], ['whole milk'], 0.5823529411764706, 0.5650694926201469))
association_rules.append((['curd', 'tropic fruit'], ['yogurt'], 0.5148514851485149, 0.5045830833591696))
association_rules.append((['beef', 'yogurt'], ['whole milk'], 0.5217391304347826, 0.5100473858231519))
association_rules.append((['frankfurt', 'yogurt'], ['whole milk'], 0.5545454545454546, 0.5433620466560687))
association_rules.append((['sausag', 'yogurt'], ['whole milk'], 0.44559585492227977, 0.4259740574436299))
association_rules.append((['veget', 'root veget', 'citru fruit'], ['whole milk'], 0.5588235294117647, 0.5484534602779705))
association_rules.append((['veget', 'whole milk', 'tropic fruit'], ['root veget'], 0.4107142857142857, 0.3936341718468599))
association_rules.append((['root veget', 'whole milk', 'tropic fruit'], ['veget'], 0.5847457627118644, 0.5727490160668868))
association_rules.append((['veget', 'root veget', 'tropic fruit'], ['whole milk'], 0.5702479338842975, 0.5579461852059729))
association_rules.append((['sausag', 'yogurt'], ['veget'], 0.41450777202072536, 0.3948859745420755))
association_rules.append((['pip fruit', 'rollsbun'], ['whole milk'], 0.44525547445255476, 0.4313270482630468))
association_rules.append((['pip fruit', 'pastri'], ['whole milk'], 0.47619047619047616, 0.46551540502333505))
association_rules.append((['pip fruit', 'root veget'], ['whole milk'], 0.5751633986928104, 0.5596082949921191))
association_rules.append((['pip fruit', 'whippedsour cream'], ['whole milk'], 0.6483516483516484, 0.6390999200067927))
association_rules.append((['pip fruit', 'domest egg'], ['whole milk'], 0.6235294117647059, 0.614887687486544))
association_rules.append((['pip fruit', 'tropic fruit'], ['whole milk'], 0.4129353233830846, 0.39250018714884305))
association_rules.append((['pip fruit', 'whole milk'], ['veget'], 0.44932432432432434, 0.41923079036743127))
association_rules.append((['pip fruit', 'veget'], ['whole milk'], 0.5175097276264592, 0.4913812201030757))
association_rules.append((['pip fruit', 'sausag'], ['whole milk'], 0.5188679245283019, 0.5080911860167118))
association_rules.append((['butter', 'root veget'], ['whole milk'], 0.6377952755905512, 0.6248835228455328))
association_rules.append((['butter', 'citru fruit'], ['whole milk'], 0.5555555555555556, 0.5464054945551489))
association_rules.append((['butter', 'tropic fruit'], ['whole milk'], 0.6224489795918368, 0.6124855798358384))
association_rules.append((['butter', 'bottl water'], ['whole milk'], 0.6022727272727273, 0.5933260009612186))
association_rules.append((['butter', 'rollsbun'], ['whole milk'], 0.49242424242424243, 0.4790041529569793))
association_rules.append((['rollsbun', 'chicken'], ['whole milk'], 0.5473684210526316, 0.5377100233299801))
association_rules.append((['rollsbun', 'root veget'], ['whole milk'], 0.5230125523012552, 0.49871405697795307))
association_rules.append((['rollsbun', 'citru fruit'], ['whole milk'], 0.4303030303030303, 0.4135279184689514))
association_rules.append((['rollsbun', 'tropic fruit'], ['whole milk'], 0.4462809917355372, 0.42167749437888813))
association_rules.append((['rollsbun', 'beef'], ['whole milk'], 0.5, 0.486376575843839))
association_rules.append((['rollsbun', 'pork'], ['whole milk'], 0.5495495495495496, 0.5382644743157147))
association_rules.append((['soda', 'root veget'], ['whole milk'], 0.4371584699453552, 0.418553345911195))
association_rules.append((['chicken', 'root veget'], ['whole milk'], 0.5514018691588785, 0.5405234633028394))
association_rules.append((['sugar', 'whole milk'], ['veget'], 0.4189189189189189, 0.4038721519404724))
association_rules.append((['sugar', 'veget'], ['whole milk'], 0.5849056603773585, 0.5741289218657684))
association_rules.append((['newspap', 'root veget'], ['whole milk'], 0.504424778761062, 0.49293636883832914))
association_rules.append((['newspap', 'tropic fruit'], ['whole milk'], 0.43103448275862066, 0.41924107080254097))
association_rules.append((['newspap', 'veget'], ['whole milk'], 0.43157894736842106, 0.4122621519231181))
association_rules.append((['fruitveget juic', 'root veget'], ['whole milk'], 0.5423728813559322, 0.5303761347109546))
association_rules.append((['fruitveget juic', 'tropic fruit'], ['whole milk'], 0.43703703703703706, 0.42331194553642704))
association_rules.append((['fruitveget juic', 'veget'], ['whole milk'], 0.4975845410628019, 0.47653940076186657))
association_rules.append((['fruitveget juic', 'bottl water'], ['whole milk'], 0.40714285714285714, 0.3929094289200023))
association_rules.append((['rollsbun', 'pastri'], ['whole milk'], 0.4077669902912621, 0.38682351733477577))
association_rules.append((['pastri', 'root veget'], ['whole milk'], 0.5185185185185185, 0.5075384453180305))
association_rules.append((['pastri', 'tropic fruit'], ['whole milk'], 0.5076923076923077, 0.49447555291394246))
association_rules.append((['root veget', 'citru fruit'], ['whole milk'], 0.5172413793103449, 0.4995512613762253))
association_rules.append((['root veget', 'tropic fruit'], ['whole milk'], 0.5700483091787439, 0.5490031688778086))
association_rules.append((['root veget', 'beef'], ['veget'], 0.45614035087719296, 0.43875523497642027))
association_rules.append((['veget', 'beef'], ['root veget'], 0.4020618556701031, 0.3823383908470043))
association_rules.append((['root veget', 'shop bag'], ['veget'], 0.5158730158730159, 0.5030629304724465))
association_rules.append((['root veget', 'pork'], ['veget'], 0.5149253731343284, 0.5013019489781674))
association_rules.append((['curd', 'root veget'], ['veget'], 0.5046728971962616, 0.4937944913402226))
association_rules.append((['sausag', 'root veget'], ['veget'], 0.4557823129251701, 0.44083721329117254))
association_rules.append((['whippedsour cream', 'domest egg'], ['veget'], 0.5102040816326531, 0.5002406818766547))
association_rules.append((['whippedsour cream', 'citru fruit'], ['veget'], 0.5233644859813084, 0.5124860801252693))
association_rules.append((['whippedsour cream', 'tropic fruit'], ['veget'], 0.5661764705882353, 0.5523497117431763))
association_rules.append((['tropic fruit', 'citru fruit'], ['veget'], 0.45408163265306123, 0.4341548331410645))
association_rules.append((['curd', 'tropic fruit'], ['veget'], 0.5148514851485149, 0.5045830833591696))
association_rules.append((['sausag', 'tropic fruit'], ['veget'], 0.4306569343065693, 0.4167285081170614))
association_rules.append((['sausag', 'bottl water'], ['veget'], 0.423728813559322, 0.4117320669143444))
association_rules.append((['pip fruit', 'veget', 'yogurt'], ['whole milk'], 0.625, 0.6168666124440829))
association_rules.append((['pip fruit', 'whole milk', 'yogurt'], ['veget'], 0.5319148936170213, 0.5223581632388188))
association_rules.append((['fruitveget juic', 'whole milk', 'yogurt'], ['veget'], 0.5376344086021505, 0.528179345568397))
association_rules.append((['fruitveget juic', 'veget', 'whole milk'], ['yogurt'], 0.4854368932038835, 0.4749651567256403))
association_rules.append((['fruitveget juic', 'veget', 'yogurt'], ['whole milk'], 0.6172839506172839, 0.6090488957169179))
association_rules.append((['root veget', 'yogurt', 'tropic fruit'], ['whole milk'], 0.7, 0.6918666124440829))
association_rules.append((['root veget', 'whole milk', 'tropic fruit'], ['yogurt'], 0.4745762711864407, 0.46257952454146306))
association_rules.append((['whippedsour cream', 'whole milk', 'yogurt'], ['veget'], 0.514018691588785, 0.5031402857327459))
association_rules.append((['whippedsour cream', 'veget', 'yogurt'], ['whole milk'], 0.55, 0.5398332655551037))
association_rules.append((['veget', 'yogurt', 'tropic fruit'], ['whole milk'], 0.6198347107438017, 0.6075329620654771))
association_rules.append((['yogurt', 'whole milk', 'tropic fruit'], ['veget'], 0.5033557046979866, 0.48820727037509115))
association_rules.append((['veget', 'whole milk', 'tropic fruit'], ['yogurt'], 0.44642857142857145, 0.42934845756114565))
association_rules.append((['veget', 'rollsbun', 'yogurt'], ['whole milk'], 0.5221238938053098, 0.510635483882577))
association_rules.append((['veget', 'root veget', 'yogurt'], ['whole milk'], 0.6062992125984252, 0.5933874598534069))
association_rules.append((['root veget', 'whole milk', 'yogurt'], ['veget'], 0.5384615384615384, 0.5239231082053367))
association_rules.append((['pip fruit', 'veget', 'root veget'], ['whole milk'], 0.675, 0.666866612444083))
association_rules.append((['pip fruit', 'root veget', 'whole milk'], ['veget'], 0.6136363636363636, 0.6046896373248549))
association_rules.append((['pip fruit', 'veget', 'whole milk'], ['root veget'], 0.40601503759398494, 0.39249328078227286))
association_rules.append((['veget', 'rollsbun', 'root veget'], ['whole milk'], 0.5083333333333333, 0.49613325199945774))
association_rules.append((['rollsbun', 'whole milk', 'root veget'], ['veget'], 0.488, 0.4752915819438796))
association_rules.append((['veget', 'whole milk', 'citru fruit'], ['root veget'], 0.4453125, 0.43229907991053274))
association_rules.append((['root veget', 'whole milk', 'citru fruit'], ['veget'], 0.6333333333333333, 0.6241832723329266))
association_rules.append((['root veget', 'bottl water'], ['whole milk'], 0.4675324675324675, 0.4518756964873272))
association_rules.append((['root veget', 'beef'], ['whole milk'], 0.4619883040935672, 0.44460318819279454))
association_rules.append((['root veget', 'shop bag'], ['whole milk'], 0.4126984126984127, 0.39988832729784335))
association_rules.append((['root veget', 'pork'], ['whole milk'], 0.5, 0.486376575843839))
association_rules.append((['brown bread', 'rollsbun'], ['whole milk'], 0.41935483870967744, 0.40674808799800605))
association_rules.append((['brown bread', 'soda'], ['whole milk'], 0.4032258064516129, 0.3906190557399415))
association_rules.append((['brown bread', 'root veget'], ['whole milk'], 0.56, 0.5498332655551037))
association_rules.append((['brown bread', 'tropic fruit'], ['whole milk'], 0.5333333333333333, 0.5226582621661922))
association_rules.append((['brown bread', 'veget'], ['whole milk'], 0.5, 0.4812932086213908))
association_rules.append((['napkin', 'rollsbun'], ['whole milk'], 0.45217391304347826, 0.4404821684318475))
association_rules.append((['napkin', 'veget'], ['whole milk'], 0.47183098591549294, 0.4573942230037402))
association_rules.append((['whippedsour cream', 'butter'], ['whole milk'], 0.66, 0.6498332655551037))
association_rules.append((['whippedsour cream', 'rollsbun'], ['whole milk'], 0.5347222222222222, 0.5200821246215716))
association_rules.append((['whippedsour cream', 'soda'], ['whole milk'], 0.47368421052631576, 0.46209413325913395))
association_rules.append((['whippedsour cream', 'root veget'], ['whole milk'], 0.5535714285714286, 0.5364913147040028))
association_rules.append((['whippedsour cream', 'domest egg'], ['whole milk'], 0.5714285714285714, 0.561465171672573))
association_rules.append((['whippedsour cream', 'citru fruit'], ['whole milk'], 0.5794392523364486, 0.5685608464804095))
association_rules.append((['whippedsour cream', 'tropic fruit'], ['whole milk'], 0.5735294117647058, 0.5597026529196468))
association_rules.append((['whippedsour cream', 'whole milk'], ['veget'], 0.45425867507886436, 0.4220301268885431))
association_rules.append((['whippedsour cream', 'veget'], ['whole milk'], 0.5070422535211268, 0.47816872769762125))
association_rules.append((['domest egg', 'butter'], ['whole milk'], 0.6210526315789474, 0.6113942338562959))
association_rules.append((['domest egg', 'rollsbun'], ['whole milk'], 0.42207792207792205, 0.40642115103278176))
association_rules.append((['domest egg', 'soda'], ['whole milk'], 0.4180327868852459, 0.4056293708624724))
association_rules.append((['domest egg', 'root veget'], ['whole milk'], 0.5957446808510638, 0.58140958528376))
association_rules.append((['domest egg', 'citru fruit'], ['whole milk'], 0.5490196078431373, 0.5386495387093431))
association_rules.append((['domest egg', 'tropic fruit'], ['whole milk'], 0.6071428571428571, 0.5957561145645732))
association_rules.append((['domest egg', 'whole milk'], ['veget'], 0.4101694915254237, 0.38017762491297963))
association_rules.append((['domest egg', 'veget'], ['whole milk'], 0.5525114155251142, 0.5302462670907913))
association_rules.append((['rollsbun', 'frozen veget'], ['whole milk'], 0.5, 0.4898332655551037))
association_rules.append((['frozen veget', 'root veget'], ['whole milk'], 0.5350877192982456, 0.5234976420310639))
association_rules.append((['margarin', 'rollsbun'], ['whole milk'], 0.5379310344827586, 0.523189269537659))
association_rules.append((['margarin', 'domest egg'], ['whole milk'], 0.6219512195121951, 0.6136144972673802))
association_rules.append((['margarin', 'veget'], ['whole milk'], 0.4690721649484536, 0.44934870012535477))
association_rules.append((['tropic fruit', 'citru fruit'], ['whole milk'], 0.45408163265306123, 0.4341548331410645))
association_rules.append((['bottl water', 'citru fruit'], ['whole milk'], 0.43609022556390975, 0.42256846875219767))
association_rules.append((['bottl water', 'tropic fruit'], ['whole milk'], 0.4340659340659341, 0.4155624773762228))
association_rules.append((['frankfurt', 'root veget'], ['whole milk'], 0.5, 0.4898332655551037))
association_rules.append((['frankfurt', 'tropic fruit'], ['whole milk'], 0.5483870967741935, 0.53893203374044))
association_rules.append((['frankfurt', 'veget'], ['whole milk'], 0.46296296296296297, 0.446492853162231))
association_rules.append((['sausag', 'pastri'], ['whole milk'], 0.45528455284552843, 0.442779469478306))
association_rules.append((['sausag', 'root veget'], ['whole milk'], 0.5170068027210885, 0.5020617030870909))
association_rules.append((['sausag', 'whippedsour cream'], ['whole milk'], 0.5617977528089888, 0.5527493591530311))
association_rules.append((['sausag', 'tropic fruit'], ['whole milk'], 0.5182481751824818, 0.5043197489929738))
association_rules.append((['oil', 'veget'], ['whole milk'], 0.5102040816326531, 0.5002406818766547))
association_rules.append((['oil', 'whole milk'], ['veget'], 0.45045045045045046, 0.4391653752166156))
association_rules.append((['pip fruit', 'root veget'], ['veget'], 0.5228758169934641, 0.5073207132927727))
association_rules.append((['pip fruit', 'whippedsour cream'], ['veget'], 0.6043956043956044, 0.5951438760507487))
association_rules.append((['pip fruit', 'citru fruit'], ['tropic fruit'], 0.40441176470588236, 0.3905850058608234))
association_rules.append((['pip fruit', 'citru fruit'], ['veget'], 0.4264705882352941, 0.41264382939023514))
association_rules.append((['pip fruit', 'tropic fruit'], ['veget'], 0.4626865671641791, 0.4422514309299376))
association_rules.append((['whippedsour cream', 'butter'], ['veget'], 0.57, 0.5598332655551036))
association_rules.append((['rollsbun', 'butter'], ['veget'], 0.42424242424242425, 0.4108223347751611))
association_rules.append((['butter', 'root veget'], ['veget'], 0.5118110236220472, 0.4988992708770289))
association_rules.append((['butter', 'tropic fruit'], ['veget'], 0.5510204081632653, 0.5410570084072669))
association_rules.append((['whippedsour cream', 'rollsbun'], ['veget'], 0.4583333333333333, 0.44369323573268266))
association_rules.append((['rollsbun', 'root veget'], ['veget'], 0.502092050209205, 0.47779355488590286))
association_rules.append((['rollsbun', 'beef'], ['veget'], 0.4253731343283582, 0.4117497101721972))
association_rules.append((['rollsbun', 'pork'], ['veget'], 0.4954954954954955, 0.4842104202616606))
association_rules.append((['domest egg', 'soda'], ['veget'], 0.4098360655737705, 0.397432649550997))
association_rules.append((['soda', 'root veget'], ['veget'], 0.4426229508196721, 0.4240178267855119))
association_rules.append((['chicken', 'root veget'], ['veget'], 0.5233644859813084, 0.5124860801252693))
association_rules.append((['newspap', 'root veget'], ['veget'], 0.5221238938053098, 0.510635483882577))
association_rules.append((['fruitveget juic', 'root veget'], ['veget'], 0.5508474576271186, 0.538850710982141))
association_rules.append((['fruitveget juic', 'tropic fruit'], ['veget'], 0.48148148148148145, 0.46775638998087143))
association_rules.append((['pastri', 'root veget'], ['veget'], 0.5370370370370371, 0.5260569638365491))
association_rules.append((['whippedsour cream', 'root veget'], ['veget'], 0.5, 0.4829198861325742))
association_rules.append((['domest egg', 'root veget'], ['veget'], 0.5106382978723404, 0.4963032023050366))
association_rules.append((['margarin', 'root veget'], ['veget'], 0.5321100917431193, 0.5210283511981824))
association_rules.append((['frozen veget', 'root veget'], ['veget'], 0.5263157894736842, 0.5147257122065024))
association_rules.append((['root veget', 'onion'], ['veget'], 0.6021505376344086, 0.5926954746006551))
association_rules.append((['veget', 'onion'], ['root veget'], 0.4, 0.3857665717771452))
association_rules.append((['root veget', 'citru fruit'], ['veget'], 0.5862068965517241, 0.5685167786176045))
association_rules.append((['root veget', 'tropic fruit'], ['veget'], 0.5845410628019324, 0.5634959225009971))
association_rules.append((['root veget', 'bottl water'], ['veget'], 0.44805194805194803, 0.43239517700680774))
association_rules.append((['veget', 'butter'], ['whole milk'], 0.5736040609137056, 0.55357559405726))
association_rules.append((['butter', 'whole milk'], ['veget'], 0.41697416974169743, 0.38942231939602845))
association_rules.append((['veget', 'rollsbun'], ['whole milk'], 0.4200477326968974, 0.37744911537278186))
association_rules.append((['veget', 'chocol'], ['whole milk'], 0.432, 0.4192915819438796))
association_rules.append((['veget', 'soda'], ['whole milk'], 0.4254658385093168, 0.3927289535967507))
association_rules.append((['veget', 'chicken'], ['whole milk'], 0.4715909090909091, 0.4536974564678916))
association_rules.append((['chicken', 'whole milk'], ['veget'], 0.4797687861271676, 0.462180335537497))
association_rules.append((['veget', 'pastri'], ['whole milk'], 0.46846846846846846, 0.44589831800079865))
association_rules.append((['veget', 'root veget'], ['whole milk'], 0.4892703862660944, 0.44189340375287767))
association_rules.append((['root veget', 'whole milk'], ['veget'], 0.47401247401247404, 0.4251104813325228))
association_rules.append((['veget', 'hygien articl'], ['whole milk'], 0.5425531914893617, 0.5329964611111592))
association_rules.append((['hygien articl', 'whole milk'], ['veget'], 0.40476190476190477, 0.39195181936133544))
association_rules.append((['veget', 'frozen veget'], ['whole milk'], 0.5428571428571428, 0.5250653575785743))
association_rules.append((['frozen veget', 'whole milk'], ['veget'], 0.472636815920398, 0.45220167968615643))
association_rules.append((['veget', 'onion'], ['whole milk'], 0.4642857142857143, 0.45005228606285946))
association_rules.append((['onion', 'whole milk'], ['veget'], 0.5462184873949579, 0.5341200734055314))
association_rules.append((['veget', 'citru fruit'], ['whole milk'], 0.4507042253521127, 0.4218306995286072))
association_rules.append((['whole milk', 'citru fruit'], ['veget'], 0.4266666666666667, 0.3961664633319778))
association_rules.append((['veget', 'tropic fruit'], ['whole milk'], 0.47592067988668557, 0.4400321072962016))
association_rules.append((['whole milk', 'tropic fruit'], ['veget'], 0.40384615384615385, 0.36155253855538527))
association_rules.append((['cream chees', 'whole milk'], ['veget'], 0.4074074074074074, 0.3909372976066754))
association_rules.append((['veget', 'cream chees'], ['whole milk'], 0.4888888888888889, 0.47516379738827885))
association_rules.append((['long life bakeri product', 'whole milk'], ['veget'], 0.42105263157894735, 0.40753087476723526))
association_rules.append((['veget', 'long life bakeri product'], ['whole milk'], 0.5333333333333333, 0.5226582621661922))
association_rules.append((['veget', 'bottl beer'], ['whole milk'], 0.4716981132075472, 0.45553300544016206))
association_rules.append((['veget', 'bottl water'], ['whole milk'], 0.4344262295081967, 0.40961939746264975))
association_rules.append((['beef', 'whole milk'], ['veget'], 0.4354066985645933, 0.41415822357476))
association_rules.append((['veget', 'beef'], ['whole milk'], 0.4690721649484536, 0.44934870012535477))
association_rules.append((['hamburg meat', 'whole milk'], ['veget'], 0.42758620689655175, 0.4128444419514521))
association_rules.append((['veget', 'hamburg meat'], ['whole milk'], 0.45588235294117646, 0.4420555940961175))
association_rules.append((['veget', 'pork'], ['whole milk'], 0.4694835680751174, 0.44782842370748827))
association_rules.append((['whole milk', 'pork'], ['veget'], 0.45871559633027525, 0.43655211524040133))
association_rules.append((['white bread', 'veget'], ['whole milk'], 0.42962962962962964, 0.4159045381290196))
association_rules.append((['curd', 'rollsbun'], ['whole milk'], 0.5858585858585859, 0.5757935187581386))
association_rules.append((['curd', 'root veget'], ['whole milk'], 0.5700934579439252, 0.5592150520878861))
association_rules.append((['curd', 'whippedsour cream'], ['whole milk'], 0.5631067961165048, 0.5526350596382616))
association_rules.append((['curd', 'tropic fruit'], ['whole milk'], 0.6336633663366337, 0.6233949645472884))
association_rules.append((['curd', 'veget'], ['whole milk'], 0.5739644970414202, 0.5567827158295454))

# %%
dataset_size = [10000, 20000, 50000, 100000, 500000 , 1000000]
csv = False

# %%
dictionary = eval(open("../Data/normalized_dictionary.txt", "r").read())
products_available = list(dictionary.keys())

# %% [markdown]
# ---
# ### **Import** section

# %%
import pandas as pd
import numpy as np
import random
import math

# %% [markdown]
# ---
# ### **Function** definitions

# %%
# Display the data
def displayAssociationRules(ars):
    arules = pd.DataFrame(ars)
    arules.columns = ["From", "To", "Confidence", "Interest"]
    arules.sort_values("Confidence", ascending=False)
    display(arules)

# %%
# Given the Association Rules, get the set of all products
# In order to be compatible with the rest of the script, it returns a list object (not a set)
def getProducts(dataset):    
    products = []
    # Extract data from each Association Rule
    for ar in dataset:
        for item in ar[0]:
            products.append(item)
        for item in ar[1]:
            products.append(item)
    products = list(set(products))
    return products

# %% [markdown]
# &nbsp;
# #### **Basket Generation**
# There are two ways to generate a basket. The *which* variable defines with half probabability either one way or the other.
# - **Completely random**, it picks a sample of the whole list of products, and extract *k* elements, where *k* is a random variable having the highest probability on 1, and the smallest on *n*, the number of available products. It is a bounded monotonic decreasing distribution.
# - **Based on the Association Rules**, accordingly to the confidences of the association rules, it extracts one of them. Then, it selects k, the size of the basket, it is a random variable centered on the half of the left side size. Finally, it decides whether to include the right item or not into the basket. This probability is given by the confidence of the choosen Association Rule too.

# %%
def generateBasket(ars, arbased, mixed=False, prod_AR_source=True, source=None):
    
    if prod_AR_source:
        products = getProducts(ars)
    else:
        products = source
    n = len(products)
    
    which_prob = [1 - arbased, arbased]
    which = np.random.choice([0, 1], p=which_prob)
    # 0 --> Completely Random
    # 1 --> Association Rule - Based
    
    if which == 0:
                
        # In order to define a decreasing probability, I define an array with length n
        # Where each element prob_dist[i] = n-i normalized with respect to the sum of 
        # the first n integer n*(n+1)/2 (in order to get a probability distribution)
        prob_dist = [i**5 + 1 for i in range(n)]
        prob_dist_sum = sum(prob_dist)
        prob_dist = [p/prob_dist_sum for p in prob_dist]
        prob_dist = prob_dist[::-1]
        
        # Create an array representing how many item it is possible extract
        # So as we can choose a number based on the probability
        how_many_products = list(range(1, n + 1))    
        k = np.random.choice(how_many_products, p=prob_dist)

        # Pick a sample of size k
        prod = random.sample(products, k)

    else:
    
        # Get the confidences of the Association Rules
        # Along with the sum of that values, in order to normalize the confidences array
        confidences = [ar[2] for ar in ars]
        conf_sum = sum(confidences)
        confidences = [conf/conf_sum for conf in confidences]
        
        # Create an array with the indexes of the possible AR
        ar_number = len(ars)        
        which_ar_pick = list(range(ar_number))
        
        # Take one of the Association Rules.
        # Use the confidences in order to define their probability distribution
        index = np.random.choice(which_ar_pick, p=confidences)
        AR = ars[index]        
        left_side = AR[0]
        rigth_side = AR[1]
        
        # As in the other case, define how many item it is possible to select
        # array_sum is used for normalizing the probabilities
        left_size = len(left_side)
        array_sum = left_size * (left_size + 1) * 0.5
        
        # Number of products available, at least one.
        # The probability distribution is centered on the half of the left side size of the AR
        how_many_products = list(range(1, left_size + 1))  
        
        # Creating the distribution for the basket size (at least)
        increasing = [5*i for i in range(2, 2 + math.floor(left_size/2))]
        decreasing = [2*i - 1.0/(2*i) for i in list(range(1, 1 + math.ceil(left_size/2)))[::-1]]
        size_dist = increasing + decreasing
        sum_array = sum(size_dist)
        size_dist = [p/sum_array for p in size_dist]

        # Pick k, and k products on the left side
        k = np.random.choice(how_many_products, p=size_dist)        
        prod = random.sample(left_side, k)

        # Consider to add the right element with probability proportional to the confidence of the AR
        right_prob = confidences[index]
        included = np.random.binomial(size=1, n=1, p=right_prob)[0]

        # If lucky
        if included == 1:
            prod.append(rigth_side[0])
            
        if mixed:
            # Add some random product
            prob_dist = [i**9 + 1 for i in range(n)]
            prob_dist_sum = sum(prob_dist)
            prob_dist = [p/prob_dist_sum for p in prob_dist]
            prob_dist = prob_dist[::-1]
            how_many_products = list(range(1, n + 1))    
            k = np.random.choice(how_many_products, p=prob_dist)
            prod_to_add = random.sample(products, k)
            for product in prod_to_add:
                prod.append(product)
            
    # Remove eventual duplicates
    prod = list(set(prod))
    return prod

# %%
def generateDataset(ars, size, arbased=0.5, mixed=False, prod_AR_source=True, source=None):
    sintetic = []
    for _ in range(size):
        sintetic.append(generateBasket(ars, arbased, mixed, prod_AR_source=prod_AR_source, source=source))
    return sintetic

# %% [markdown]
# #### **Save on file**

# %%
def export(ds, fname, aligned=True, with_title=False):
    
    # Get the maximum number of item in a basket
    max_basket_size = 0
    for basket in ds:
        if len(basket) > max_basket_size:
            max_basket_size = len(basket)
    
    file = open(fname, "w+")
    
    # Write the title if required
    if with_title:
        title = ""
        for i in range(1, max_basket_size + 1):
            title += "Product" + str(i) + ","
        title = title[:-1]
        file.write(title + "\n")
    
    # To CSV
    for basket in ds:
        bskt = ""
        for item in basket:
            bskt += item + ","
            
        if csv:
            for _ in range(max_basket_size - len(basket)):            
                bskt += ","
                
        bskt = bskt[:-1]
        file.write(bskt + "\n")
        
    file.close()

# %% [markdown]
# ---
# ## **Execution**

# %%
dataset = generateDataset(association_rules, 10000, arbased=0.6, mixed=True, prod_AR_source=True, source=products_available)

# %%
fname = "test01.csv"
export(dataset, "../Data/sintetic/" + fname, with_title=False)

# %% [markdown]
# ---

# %%
for i in dataset_size:
    print("Size: " + str(i))
    dataset = generateDataset(association_rules, i, arbased=0.6, mixed=True, prod_AR_source=True, source=products_available)
    fname = "test" + str(i) + ".csv"
    export(dataset, "../Data/sintetic/" + fname, with_title=False)
    print("End size: ", str(i))
# Out:
# Size: 10000
# End size:  10000
# Size: 20000
# End size:  20000
# Size: 50000
# End size:  50000
# Size: 100000
# End size:  100000
# Size: 500000
# End size:  500000
# Size: 1000000
# End size:  1000000
