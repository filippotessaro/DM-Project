# %%
f = open("./data/groceries.csv")
cnt = f.read()

# %%
csv = open("./data/groceries_aligned.csv", "w")

# %%
rows = cnt.split("\n")

mmax = 0
for r in rows:
    mmax = max([len(r.split(",")), mmax])
    
for i in range(mmax - 1):
    csv.write("Product" + str(i+1) + ",")

csv.write("Product" + str(mmax))
csv.write("\n")

for r in rows:
    tokens = r.split(",")
    diff = mmax - len(tokens)
    
    toadd = ""
    for _ in range(diff):
        toadd += ","
    
    final = r + toadd + "\n"
    csv.write(final)
    
csv.close()

# %%
import numpy as np 
import pandas as pd 
from mlxtend.frequent_patterns import apriori, association_rules

# %%
data = pd.read_csv("./data/groceries_aligned.csv") 
data.head()
# Out:
#            Product1             Product2        Product3  \
# 0      citrus fruit  semi-finished bread       margarine
# 1    tropical fruit               yogurt          coffee
# 2        whole milk                  NaN             NaN
# 3         pip fruit               yogurt    cream cheese
# 4  other vegetables           whole milk  condensed milk
#
#                    Product4 Product5 Product6 Product7 Product8 Product9  \
# 0               ready soups      NaN      NaN      NaN      NaN      NaN
# 1                       NaN      NaN      NaN      NaN      NaN      NaN
# 2                       NaN      NaN      NaN      NaN      NaN      NaN
# 3              meat spreads      NaN      NaN      NaN      NaN      NaN
# 4  long life bakery product      NaN      NaN      NaN      NaN      NaN
#
#   Product10  ... Product23 Product24 Product25 Product26 Product27 Product28  \
# 0       NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# ...

# %%
data.columns
# Out:
# Index(['Product1', 'Product2', 'Product3', 'Product4', 'Product5', 'Product6',
#        'Product7', 'Product8', 'Product9', 'Product10', 'Product11',
#        'Product12', 'Product13', 'Product14', 'Product15', 'Product16',
#        'Product17', 'Product18', 'Product19', 'Product20', 'Product21',
#        'Product22', 'Product23', 'Product24', 'Product25', 'Product26',
#        'Product27', 'Product28', 'Product29', 'Product30', 'Product31',
#        'Product32'],
#       dtype='object')

# %%
ds = pd.read_csv("./data/groceries_aligned.csv")

# %%
prod = set([])
for col in ds:
    
    
    print(ds.loc[9834][col])
# Out:
# chicken
# tropical fruit
# other vegetables
# vinegar
# shopping bags
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
frq_items = apriori(ds, min_support = 0.05, use_colnames = True) 
  
# Collecting the inferred rules in a dataframe 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False]) 
print(rules.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-cda2cb09dff0> in <module>
# ----> 1 frq_items = apriori(ds, min_support = 0.05, use_colnames = True)
#       2
#       3 # Collecting the inferred rules in a dataframe
#       4 rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
#       5 rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
#
# ~/.local/lib/python3.6/site-packages/mlxtend/frequent_patterns/apriori.py in apriori(df, min_support, use_colnames, max_len, verbose, low_memory)
#     149         s = ('The allowed values for a DataFrame'
#     150              ' are True, False, 0, 1. Found value %s' % (val))
# --> 151         raise ValueError(s)
#     152
#     153     is_sparse = hasattr(df, "to_coo")
#
# ValueError: The allowed values for a DataFrame are True, False, 0, 1. Found value citrus fruit
